# %%
import re

# %%
text = """I am Deepak Mittal with my contact number 8802272797 and one more
(880)-2272-797 with email as dmittal9925.dm@gmail.com and
dmittal07.dm@yahoo.com and my order number is 123456789"""

pattern = '[a-zA-Z0-9_.]*@[a-zA-Z0-9_.]*\.com'
pattern_2 =  '[a-zA-Z0-9_.]*@[a-zA-Z0-9_.]*\.[a-zA-Z0-9_.]*'

matches = re.findall(pattern_2, text)
email = matches[0]

pattern = '\d{10}| \(\d{3}\)-\d{4}-\d{3}'
matches = re.findall(pattern, text)
contact = matches[0]

pattern = "order [^\d]*(\d*)"
matches = re.findall(pattern, text)
order = matches[0]

order, contact, email
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\.'
# <>:6: SyntaxWarning: invalid escape sequence '\.'
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# <>:15: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\.'
# <>:6: SyntaxWarning: invalid escape sequence '\.'
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# <>:15: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_491/3544355114.py:5: SyntaxWarning: invalid escape sequence '\.'
#   pattern = '[a-zA-Z0-9_.]*@[a-zA-Z0-9_.]*\.com'
# /tmp/ipykernel_491/3544355114.py:6: SyntaxWarning: invalid escape sequence '\.'
#   pattern_2 =  '[a-zA-Z0-9_.]*@[a-zA-Z0-9_.]*\.[a-zA-Z0-9_.]*'
# /tmp/ipykernel_491/3544355114.py:11: SyntaxWarning: invalid escape sequence '\d'
#   pattern = '\d{10}| \(\d{3}\)-\d{4}-\d{3}'
# /tmp/ipykernel_491/3544355114.py:15: SyntaxWarning: invalid escape sequence '\d'
#   pattern = "order [^\d]*(\d*)"
# ...
